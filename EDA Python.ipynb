# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("music_genre.csv")
# To display the top 5 rows 
df.head(10)  
#lo que es redundante es el 5 porque el head por default te imprime 5.
# Out:
#    instance_id           artist_name            track_name  popularity  \
# 0      32894.0              Röyksopp  Röyksopp's Night Out        27.0
# 1      46652.0  Thievery Corporation      The Shining Path        31.0
# 2      30097.0        Dillon Francis             Hurricane        28.0
# 3      62177.0              Dubloadz                 Nitro        34.0
# 4      24907.0           What So Not      Divide & Conquer        32.0
# 5      89064.0            Axel Boman                 Hello        47.0
# 6      43760.0        Jordan Comolli                 Clash        46.0
# 7      30738.0                Hraach               Delirio        43.0
# 8      84950.0                 Kayzo           NEVER ALONE        39.0
# 9      56950.0                Shlump            Lazer Beam        22.0
#
#    acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 0       0.00468         0.652         -1.0   0.941          0.792000  A#
# ...

# %%
df.tail(5) 
# To display the botton 5 rows
# Out:
#        instance_id        artist_name                track_name  popularity  \
# 50000      58878.0              BEXEY                  GO GETTA        59.0
# 50001      43557.0          Roy Woods       Drama (feat. Drake)        72.0
# 50002      39767.0             Berner  Lovin' Me (feat. Smiggz)        51.0
# 50003      57944.0          The-Dream         Shawty Is Da Shit        65.0
# 50004      63470.0  Naughty By Nature            Hip Hop Hooray        67.0
#
#        acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 50000       0.03340         0.913         -1.0   0.574               0.0  C#
# 50001       0.15700         0.709     251860.0   0.362               0.0   B
# 50002       0.00597         0.693     189483.0   0.763               0.0   D
# 50003       0.08310         0.782     262773.0   0.472               0.0   G
# 50004       0.10200         0.862     267267.0   0.642               0.0  F#
#
# ...

# %%
df.shape
# Out:
# (50005, 18)

# %%
df.columns
# Out:
# Index(['instance_id', 'artist_name', 'track_name', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'obtained_date', 'valence', 'music_genre'],
#       dtype='object')

# %%
df.dtypes
# Out:
# instance_id         float64
# artist_name          object
# track_name           object
# popularity          float64
# acousticness        float64
# danceability        float64
# duration_ms         float64
# energy              float64
# instrumentalness    float64
# key                  object
# liveness            float64
# loudness            float64
# mode                 object
# speechiness         float64
# tempo                object
# obtained_date        object
# valence             float64
# music_genre          object
# dtype: object

# %%
df.describe().transpose()
# el de duration_ms no puede tener valores negativos
# Out:
#                     count           mean            std           min  \
# instance_id       50000.0   55888.396360   20725.256253  20002.000000
# popularity        50000.0      44.220420      15.542008      0.000000
# acousticness      50000.0       0.306383       0.341340      0.000000
# danceability      50000.0       0.558241       0.178632      0.059600
# duration_ms       50000.0  221252.602860  128671.957157     -1.000000
# energy            50000.0       0.599755       0.264559      0.000792
# instrumentalness  50000.0       0.181601       0.325409      0.000000
# liveness          50000.0       0.193896       0.161637      0.009670
# loudness          50000.0      -9.133761       6.162990    -47.046000
# speechiness       50000.0       0.093586       0.101373      0.022300
# valence           50000.0       0.456264       0.247119      0.000000
#
#                           25%            50%            75%          max
# ...

# %%
df.describe(include=['O'])
# Se ve que hay empty_field y que hay un ? en tempo
# Out:
#         artist_name track_name    key   mode  tempo obtained_date music_genre
# count         50000      50000  50000  50000  50000         50000       50000
# unique         6863      41699     12      2  29394             5          10
# top     empty_field       Home      G  Major      ?         4-Apr  Electronic
# freq           2489         16   5727  32099   4980         44748        5000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50005 entries, 0 to 50004
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instance_id       50000 non-null  float64
#  1   artist_name       50000 non-null  object
#  2   track_name        50000 non-null  object
#  3   popularity        50000 non-null  float64
#  4   acousticness      50000 non-null  float64
#  5   danceability      50000 non-null  float64
#  6   duration_ms       50000 non-null  float64
#  7   energy            50000 non-null  float64
#  8   instrumentalness  50000 non-null  float64
#  9   key               50000 non-null  object
#  10  liveness          50000 non-null  float64
#  11  loudness          50000 non-null  float64
#  12  mode              50000 non-null  object
#  13  speechiness       50000 non-null  float64
#  14  tempo             50000 non-null  object
#  15  obtained_date     50000 non-null  object
# ...

# %%
duplicate_rows_df = df[df.duplicated()]
# duplicate_rows_df.shape
duplicate_rows_df
# Out:
#        instance_id artist_name track_name  popularity  acousticness  \
# 10001          NaN         NaN        NaN         NaN           NaN
# 10002          NaN         NaN        NaN         NaN           NaN
# 10003          NaN         NaN        NaN         NaN           NaN
# 10004          NaN         NaN        NaN         NaN           NaN
#
#        danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 10001           NaN          NaN     NaN               NaN  NaN       NaN
# 10002           NaN          NaN     NaN               NaN  NaN       NaN
# 10003           NaN          NaN     NaN               NaN  NaN       NaN
# 10004           NaN          NaN     NaN               NaN  NaN       NaN
#
#        loudness mode  speechiness tempo obtained_date  valence music_genre
# 10001       NaN  NaN          NaN   NaN           NaN      NaN         NaN
# 10002       NaN  NaN          NaN   NaN           NaN      NaN         NaN
# ...

# %%
# Percentage duplicated rows
percentage = len(duplicate_rows_df)/ len(df)* 100
print("Percentage of duplicated rows {0}%".format(round(percentage,6)))
# Out:
# Percentage of duplicated rows 0.007999%

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (50001, 18)

# %%
print(df.isnull().sum())
# Out:
# instance_id         1
# artist_name         1
# track_name          1
# popularity          1
# acousticness        1
# danceability        1
# duration_ms         1
# energy              1
# instrumentalness    1
# key                 1
# liveness            1
# loudness            1
# mode                1
# speechiness         1
# tempo               1
# obtained_date       1
# valence             1
# music_genre         1
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#        instance_id artist_name track_name  popularity  acousticness  \
# 10000          NaN         NaN        NaN         NaN           NaN
#
#        danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 10000           NaN          NaN     NaN               NaN  NaN       NaN
#
#        loudness mode  speechiness tempo obtained_date  valence music_genre
# 10000       NaN  NaN          NaN   NaN           NaN      NaN         NaN

# %%
df = df.dropna()

# %%
print(df.isnull().sum())
# Out:
# instance_id         0
# artist_name         0
# track_name          0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# obtained_date       0
# valence             0
# music_genre         0
# dtype: int64

# %%
df_lower = df.applymap(lambda s:s.lower() if type(s) == str else s)

# %%
df.head()
# Out:
#    instance_id           artist_name            track_name  popularity  \
# 0      32894.0              Röyksopp  Röyksopp's Night Out        27.0
# 1      46652.0  Thievery Corporation      The Shining Path        31.0
# 2      30097.0        Dillon Francis             Hurricane        28.0
# 3      62177.0              Dubloadz                 Nitro        34.0
# 4      24907.0           What So Not      Divide & Conquer        32.0
#
#    acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 0       0.00468         0.652         -1.0   0.941           0.79200  A#
# 1       0.01270         0.622     218293.0   0.890           0.95000   D
# 2       0.00306         0.620     215613.0   0.755           0.01180  G#
# 3       0.02540         0.774     166875.0   0.700           0.00253  C#
# 4       0.00465         0.638     222369.0   0.587           0.90900  F#
#
#    liveness  loudness   mode  speechiness               tempo obtained_date  \
# ...

# %%
duplicates = df[df.duplicated()]
duplicates.shape
# Out:
# (0, 18)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot = True, center=0);
# Out:
# C:\Users\s.moreyra.maida\AppData\Local\Temp\ipykernel_26092\2445201384.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True, center=0);

# %%
df.count()
# Out:
# instance_id         50000
# artist_name         50000
# track_name          50000
# popularity          50000
# acousticness        50000
# danceability        50000
# duration_ms         50000
# energy              50000
# instrumentalness    50000
# key                 50000
# liveness            50000
# loudness            50000
# mode                50000
# speechiness         50000
# tempo               50000
# obtained_date       50000
# valence             50000
# music_genre         50000
# dtype: int64

# %% [markdown]
# # Artist name

# %%
# df2 = df.groupby(['artist_name'])['artist_name'].count()
df2 = df.groupby(['artist_name'], as_index = False).agg(amount = ('artist_name', 'count'))

# %%
df2.head(25)
# Out:
#             artist_name  amount
# 0                   !!!      22
# 1   "Weird Al" Yankovic       1
# 2                  $NOT       3
# 3          $tupid Young       1
# 4           $uicideBoy$      92
# 5            (Hed) P.E.       2
# 6        (Sandy) Alex G       1
# 7             03 Greedo       5
# 8    04 Limited Sazabys       7
# 9             070 Shake       2
# 10             10 Years       9
# 11       10,000 Maniacs       1
# 12             1000mods       2
# 13                 10cc       2
# 14        11 Acorn Lane       3
# 15                  112       9
# 16                  116       1
# 17                11:11       4
# 18            12 Stones       3
# 19          12th Planet      11
# 20                  164       2
# 21               1788-L       3
# 22              1K Phew       2
# 23             1takejay       2
# 24             2 Chainz      44

# %%
df3 = df2.sort_values('amount',ascending = False)
df3.head()
# Out:
#                   artist_name  amount
# 6763              empty_field    2489
# 4303            Nobuo Uematsu     429
# 6581  Wolfgang Amadeus Mozart     402
# 3650     Ludwig van Beethoven     317
# 2923    Johann Sebastian Bach     314

# %%
top_10 = df3.iloc[1:10]
plt.figure(figsize=(8,8))
chart = sns.barplot(data = top_10, x = "artist_name", y = "amount")
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()

# %%
percentage_empty_field = len(df[df['artist_name']=='empty_field'])/len(df)*100
print("Percentage of duplicated rows {0}%".format(round(percentage_empty_field,6)))
# Out:
# Percentage of duplicated rows 4.978%

# %% [markdown]
# # Popularidad por artista

# %%
df2 = df.groupby(['artist_name'], as_index = False).agg(average_popularity = ('popularity', 'mean'))
df2.head()
# Out:
#            artist_name  average_popularity
# 0                  !!!           42.000000
# 1  "Weird Al" Yankovic           53.000000
# 2                 $NOT           57.666667
# 3         $tupid Young           58.000000
# 4          $uicideBoy$           60.206522

# %%
df3 = df2.sort_values('average_popularity',ascending = False)
more_popular_30 = df3.iloc[1:30]
plt.figure(figsize=(8,8))
chart = sns.barplot(data = more_popular_30, x = "artist_name", y = "average_popularity")
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()

# %%
df3.tail()
# Out:
#              artist_name  average_popularity
# 570                 Bebe                 0.0
# 525                Bajka                 0.0
# 404        Arthur Conley                 0.0
# 4867  Richard Danielpour                 0.0
# 4569     Peter Schickele                 0.0

# %%
least_popular_30 = df3.iloc[-10:-1]
plt.figure(figsize=(8,8))
chart = sns.barplot(data = least_popular_30, x = "artist_name", y = "average_popularity")
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()

# %% [markdown]
# # Artistas y tracks duplicados

# %%
duplicated_artist = df[df.duplicated(subset=['artist_name','track_name'], keep=False)]

# %%
duplicated_artist.head()
# Out:
#      instance_id      artist_name      track_name  popularity  acousticness  \
# 84       88574.0    Primal Scream    Movin' on Up        50.0        0.0846
# 89       59101.0         Gramatik   Future Crypto        34.0        0.1660
# 140      76146.0  LCD Soundsystem  All My Friends        61.0        0.1480
# 169      81568.0         Kasabian            Fire        66.0        0.0874
# 170      89847.0              Aim       The Force        50.0        0.0128
#
#      danceability  duration_ms  energy  instrumentalness key  liveness  \
# 84          0.508     230533.0   0.808          0.000727   C    0.0719
# 89          0.637     206118.0   0.472          0.105000   B    0.1430
# 140         0.701     462267.0   0.788          0.625000   D    0.0977
# 169         0.525     252280.0   0.741          0.147000  A#    0.1170
# 170         0.922     245947.0   0.701          0.000822   E    0.0941
#
#      loudness   mode  speechiness               tempo obtained_date  valence  \
# ...

# %% [markdown]
# # Music genre
